# %%
from google.colab import drive
import os

drive.mount('/content/drive/')
os.chdir('drive/MyDrive/DeepLearning/Proj1')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from python_scripts import *

# %%
# %run -i gen_figures_results.py
# Out:
# All runs are done 15 times with 50 epochs
#
# #######################################################
# Part 1 - Training of a MLP and a ConvNet trained on the targets without any weight-sharing or auxiliary losses:
#
# Loading results...
#
# For a MLP with 98902 parameters:
# Mean best test accuracy = 80.69%(+-1.54)
#
# For a ConvNet with 92050 parameters:
# Mean best test accuracy = 83.39%(+-1.08)
#
# #######################################################
# Part 2 - Training of a MLP and a ConvNet trained on the AuxModel (the Siamese model) with/without weight-sharing, but no auxiliary losses:
#
# Loading results...
#
# For a MLP with Weight-Sharing = False and 93622 parameters:
# 	Mean best test accuracy = 81.02%(+-1.27)
#
# For a MLP with Weight-Sharing = True and 47962 parameters:
# 	Mean best test accuracy = 83.35%(+-1.32)
#
# For a ConvNet with Weight-Sharing = False and 93214 parameters:
# 	Mean best test accuracy = 84.23%(+-1.06)
#
# ...
